# %%
# Python 3.13에서는 아직 TensorFlow가 공식 지원안됨. Python 3.11 이하 (특히 3.9, 3.10, 3.11) 사용 권고.

# 여러 버전의 Python을 설치하고 관리해야 한다면, pyenv 또는 anaconda 등으로 여러 버전의 Python 설치 후 프로젝트별 버전 전환 관리할 수 있음
# 또는 직접 수동으로 각각 Python 버전 설치도 가능하나 각 실행 파일 디렉토리 위치 경로를 수작업으로 관리 필요.
# 🧑‍💻 파이썬 버전 제어 및 범용 개발이 중심이라면 → ✅ pyenv + venv/poetry 조합 권장
# 🎯 데이터 과학/머신러닝 중심이라면 → ✅ Anaconda (또는 Miniconda) 추천
# 📦 빠른 개발 및 배포 → ✅ forge는 최근 등장한 관리 도구로 Jupyter 환경설정 별도 필요, 패키지 배포 자동화 및 GPU 지원 약함
# 🧪 모두 다 설치했을 경우 → 하나의 목적에만 집중해 사용하는 것이 충돌 방지에 좋음

# Python 버전 낮추기 : 

# 또는 pyenv 설치 후, pyenv install 3.10.13
# pyenv global 3.10.13   # 또는 pyenv local 3.10.13 (현재 폴더만)
# pip install numpy matplotlib pandas scikit-learn tensorflow

# anaconda (https://www.anaconda.com/products/distribution) 설치 후 
# conda create -n tf python=3.10
# conda activate tf
# pip install numpy matplotlib pandas scikit-learn tensorflow

# Installing the packeges
# !pip install numpy matplotlib pandas scikit-learn tensorflow

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

import math
from sklearn.metrics import mean_squared_error

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
# Connectiing Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Loading the data
dataset = pd.read_csv('/Users/phoenix/Eagle/2025_FastAPI/service_model/model_serving/server/uploaded_files/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# Checking for missing values
# 2016년도이전 데이터에서 2번째 컬럼 값을 가져와서 저장합니다.
training_set = dataset[:'2016'].iloc[:,1:2].values
# 2017년도이후 데이터에서 2번째 컬럼 값을 가져와서 저장합니다.
test_set = dataset['2017':].iloc[:,1:2].values

# We have chosen 'High' attribute for prices. Let's see what it looks like
dataset["High"][:'2016'].plot(figsize=(16,4),legend=True)
dataset["High"]['2017':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# Since LSTMs store long term memory state, we create a data structure with 60 timesteps and 1 output
# So for each element of training set, we have 60 previous training set elements
X_train = []
y_train = []
# LSTM 시계열 분석을 위해, Timesteps를 60으로 할 것이므로 60행 이후 데이터부터 사용 가능
# 데이터 셋을 보면, 2016년 데이터가 전체 2769개 존재함
for i in range(60,2769): 
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping X_train for efficient modelling
# Timesteps와 MinMaxScaler 등을 적용한 대상 데이터를, LTSM Layer 입력에 용이하게 재배치
# shape[0]는 전체 행의 갯수, shape[1]은 전체 열의 갯수인데.. 상기 np 배열에 넣은 형태로 여기서는 잘라낸 Timesteps 갯수
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
# X_train = np.reshape(X_train, (2709,60,1))을 뜻하며, 2016년이전 2709개의 행을 60개씩 끊어낸 값 1행으로 
# LSTM (시계열성 데이터 변경 이력 예측에 특화된 RNN모델) input_shape에 맞게 3차원 배열로 재구성

# The LSTM architecture
regressor = Sequential()
# First LSTM layer with Dropout regularisation
# 50개의 노드를 사용하여 RNN, LSTM 방식으로 입력층, 은닉층 생성 (최초 레이어는 입력층, 은닉층 동시 적용)
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
# 전체 가능한 데이터 범위는 2709행에 대해서 60개 단위로 자동 계산되므로 생략
# 60개씩 끊어내서, 1개의 Feature에 대해서 예측
regressor.add(Dropout(0.2))
# 데이터 가중치가 특정하게 치우치는 등 과적합화 등을 예방하기 위해서 Dropout 랜덤 적용
# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
# The output layer
regressor.add(Dense(units=1))
# 최종 결과가 60개씩 시계열 이력 데이터를 끊어낸 단위에 대해 학습한 결과, 값 예측이므로 마지막 노드는 1개로 처리
# 단, MNIST 이미지 데이터와 같이, 0~9까지 표현을 위해 최종 노드를 사용하는 경우 10개 노드 필요

# Compiling the RNN
regressor.compile(optimizer='rmsprop',loss='mean_squared_error')
# Fitting to the training set
regressor.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# /Users/phoenix/Library/Caches/pypoetry/virtualenvs/model-serving-Z-OfUhPm-py3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - loss: 0.0481
# Epoch 2/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0111
# Epoch 3/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0083
# Epoch 4/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0073
# Epoch 5/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0063
# Epoch 6/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0067
# Epoch 7/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0048
# Epoch 8/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0046
# Epoch 9/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0047
# Epoch 10/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0045
# Epoch 11/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0040
# Epoch 12/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0043
# Epoch 13/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0036
# Epoch 14/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0035
# Epoch 15/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0033
# Epoch 16/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0031
# Epoch 17/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0034
# Epoch 18/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0032
# Epoch 19/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0029
# Epoch 20/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0028
# Epoch 21/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0024
# Epoch 22/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0027
# Epoch 23/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0026
# Epoch 24/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0027
# Epoch 25/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0024
# Epoch 26/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0023
# Epoch 27/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0023
# Epoch 28/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0022
# Epoch 29/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0023
# Epoch 30/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0020
# Epoch 31/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0021
# Epoch 32/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0022
# Epoch 33/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0020
# Epoch 34/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0018
# Epoch 35/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0017
# Epoch 36/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0019
# Epoch 37/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0018
# Epoch 38/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0019
# Epoch 39/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0019
# Epoch 40/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0017
# Epoch 41/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0018
# Epoch 42/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0017
# Epoch 43/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0017
# Epoch 44/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0016
# Epoch 45/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0018
# Epoch 46/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0017
# Epoch 47/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0016
# Epoch 48/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0016
# Epoch 49/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0016
# Epoch 50/50
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0015

# %%
# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 4.512138869810413.

# %%
# 1. 모델 저장하기
from keras.models import load_model

# regressor.save('/content/drive/MyDrive/data/stock_lstm_model_nogpu.h5')
regressor.save('/Users/phoenix/Eagle/2025_FastAPI/service_model/model_serving/server/model/stock_lstm_model_nogpu.keras')

# %%
# 2. 모델 불러오기
import pandas as pd
from keras.models import load_model

# Connectiing Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Loading the model
model = load_model('/Users/phoenix/Eagle/2025_FastAPI/service_model/model_serving/server/model/stock_lstm_model_nogpu.keras')

# Loading the data
dataset = pd.read_csv('/Users/phoenix/Eagle/2025_FastAPI/service_model/model_serving/server/uploaded_files/IBM_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])

# We have chosen 'High' attribute for prices.
dataset.head()
# Out:
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
# 3. 모델 아키텍처 보기
from keras.utils import plot_model
import pydot
import graphviz

# plot_model(model, to_file='/content/drive/MyDrive/data/model.png')
# plot_model(model, to_file='/content/drive/MyDrive/data/model_shapes.png', show_shapes=True)

plot_model(model, to_file='/Users/phoenix/Eagle/2025_FastAPI/service_model/model_serving/server/model-images/model_service.png')
plot_model(model, to_file='/Users/phoenix/Eagle/2025_FastAPI/service_model/model_serving/server/model-images/model_shapes.png', show_shapes=True)

# %%
# 4. 모델 사용하기
'''사용 순서
1. 데이터 파일을 입력 받아서 IBM_2006-01-01_to_2018-01-01.csv
2. 로딩한 모델로 예측한 후에 stock_lstm_model.keras
3. 결과를 stock.png 파일로 생성하여 내보내는 순서'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
# from keras.models import Sequential # 모델 학습 시에 사용하였으나, 모델을 재사용하는 것이므로 불필요
# from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional # 모델 학습 시에 사용하였으나, 모델을 재사용하는 것이므로 불필요
import math
from sklearn.metrics import mean_squared_error

# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
  # plt.show()
  # plt.savefig('/content/drive/MyDrive/data/stock.png')
    plt.savefig('/Users/phoenix/Eagle/2025_FastAPI/service_model/model_serving/server/model-images/stock.png')  

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# Checking for missing values
training_set = dataset[:'2016'].iloc[:,1:2].values
test_set = dataset['2017':].iloc[:,1:2].values

# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 4.512138869810413.

# %%
import sys
print(sys.version)
# Out:
# 3.11.5 (main, Sep 11 2023, 08:31:25) [Clang 14.0.6 ]

# %%
# !poetry show
# Out:
# absl-py                      2.1.0       Abseil Python Common Libraries, se...
# annotated-types              0.7.0       Reusable constraint types to use w...
# anyio                        4.8.0       High level compatibility layer for...
# appnope                      0.1.4       Disable App Nap on macOS >= 10.9
# asttokens                    3.0.0       Annotate AST trees with source cod...
# astunparse                   1.6.3       An AST unparser for Python
# certifi                      2025.1.31   Python package for providing Mozil...
# charset-normalizer           3.4.1       The Real First Universal Charset D...
# click                        8.1.8       Composable command line interface ...
# comm                         0.2.2       Jupyter Python Comm implementation...
# contourpy                    1.3.1       Python library for calculating con...
# cycler                       0.12.1      Composable style cycles
# debugpy                      1.8.12      An implementation of the Debug Ada...
# decorator                    5.2.1       Decorators for Humans
# executing                    2.2.0       Get the currently executing AST no...
# fastapi                      0.115.8     FastAPI framework, high performanc...
# flatbuffers                  25.2.10     The FlatBuffers serialization form...
# fonttools                    4.56.0      Tools to manipulate font files
# gast                         0.6.0       Python AST that abstracts the unde...
# google-pasta                 0.2.0       pasta is an AST-based Python refac...
# graphviz                     0.20.3      Simple Python interface for Graphviz
# grpcio                       1.70.0      HTTP/2-based RPC framework
# h11                          0.14.0      A pure-Python, bring-your-own-I/O ...
# h5py                         3.13.0      Read and write HDF5 files from Python
# httptools                    0.6.4       A collection of framework independ...
# idna                         3.10        Internationalized Domain Names in ...
# ipykernel                    6.29.5      IPython Kernel for Jupyter
# ipython                      8.32.0      IPython: Productive Interactive Co...
# jedi                         0.19.2      An autocompletion tool for Python ...
# joblib                       1.4.2       Lightweight pipelining with Python...
# jupyter-client               8.6.3       Jupyter protocol implementation an...
# jupyter-core                 5.7.2       Jupyter core package. A base packa...
# keras                        3.8.0       Multi-backend Keras
# kiwisolver                   1.4.8       A fast implementation of the Casso...
# libclang                     18.1.1      Clang Python Bindings, mirrored fr...
# markdown                     3.7         Python implementation of John Grub...
# markdown-it-py               3.0.0       Python port of markdown-it. Markdo...
# markupsafe                   3.0.2       Safely add untrusted strings to HT...
# matplotlib                   3.10.0      Python plotting package
# matplotlib-inline            0.1.7       Inline Matplotlib backend for Jupyter
# mdurl                        0.1.2       Markdown URL utilities
# ml-dtypes                    0.4.1
# namex                        0.0.8       A simple utility to separate the i...
# nest-asyncio                 1.6.0       Patch asyncio to allow nested even...
# numpy                        2.0.2       Fundamental package for array comp...
# opt-einsum                   3.4.0       Path optimization of einsum functi...
# optree                       0.14.0      Optimized PyTree Utilities.
# packaging                    24.2        Core utilities for Python packages
# pandas                       2.2.3       Powerful data structures for data ...
# parso                        0.8.4       A Python Parser
# pexpect                      4.9.0       Pexpect allows easy control of int...
# pillow                       11.1.0      Python Imaging Library (Fork)
# platformdirs                 4.3.6       A small Python package for determi...
# prompt-toolkit               3.0.50      Library for building powerful inte...
# protobuf                     5.29.3
# psutil                       7.0.0       Cross-platform lib for process and...
# ptyprocess                   0.7.0       Run a subprocess in a pseudo terminal
# pure-eval                    0.2.3       Safely evaluate AST nodes without ...
# pydantic                     2.10.6      Data validation using Python type ...
# pydantic-core                2.27.2      Core functionality for Pydantic va...
# pydot                        3.0.4       Python interface to Graphviz's Dot
# pygments                     2.19.1      Pygments is a syntax highlighting ...
# pyparsing                    3.2.1       pyparsing module - Classes and met...
# python-dateutil              2.9.0.post0 Extensions to the standard Python ...
# python-dotenv                1.0.1       Read key-value pairs from a .env f...
# python-multipart             0.0.20      A streaming multipart parser for P...
# pytz                         2025.1      World timezone definitions, modern...
# pyyaml                       6.0.2       YAML parser and emitter for Python
# pyzmq                        26.2.1      Python bindings for 0MQ
# requests                     2.32.3      Python HTTP for Humans.
# rich                         13.9.4      Render rich text, tables, progress...
# scikit-learn                 1.6.1       A set of python modules for machin...
# scipy                        1.15.2      Fundamental algorithms for scienti...
# setuptools                   75.8.2      Easily download, build, install, u...
# six                          1.17.0      Python 2 and 3 compatibility utili...
# sniffio                      1.3.1       Sniff out which async library your...
# sqlalchemy                   2.0.38      Database Abstraction Library
# stack-data                   0.6.3       Extract data from python stack fra...
# starlette                    0.45.3      The little ASGI library that shines.
# tensorboard                  2.18.0      TensorBoard lets you watch Tensors...
# tensorboard-data-server      0.7.2       Fast data loading for TensorBoard
# tensorflow                   2.18.0      TensorFlow is an open source machi...
# tensorflow-io-gcs-filesystem 0.37.1      TensorFlow IO
# termcolor                    2.5.0       ANSI color formatting for output i...
# threadpoolctl                3.5.0       threadpoolctl
# tornado                      6.4.2       Tornado is a Python web framework ...
# traitlets                    5.14.3      Traitlets Python configuration system
# typing-extensions            4.12.2      Backported and Experimental Type H...
# tzdata                       2025.1      Provider of IANA time zone data
# urllib3                      2.3.0       HTTP library with thread-safe conn...
# uvicorn                      0.34.0      The lightning-fast ASGI server.
# uvloop                       0.21.0      Fast implementation of asyncio eve...
# watchfiles                   1.0.4       Simple, modern and high performanc...
# wcwidth                      0.2.13      Measures the displayed width of un...
# websockets                   15.0        An implementation of the WebSocket...
# werkzeug                     3.1.3       The comprehensive WSGI web applica...
# wheel                        0.45.1      A built-package format for Python
# wrapt                        1.17.2      Module for decorators, wrappers an...
